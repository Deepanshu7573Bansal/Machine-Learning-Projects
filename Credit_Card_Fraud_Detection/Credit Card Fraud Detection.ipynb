# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('fraudTrain.csv')
ft = pd.read_csv('fraudTest.csv')
ft1 = pd.read_csv('fraudTest.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# 4                 fraud_Keeling-Crist       misc_pos   41.96      Tyler
#
#       last gender                        street  ...      lat      long  \
# 0    Banks      F                561 Perry Cove  ...  36.0788  -81.1781
# ...

# %%
ft.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# ...

# %%
ft1.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# ...

# %%
df.shape
# Out:
# (1296675, 23)

# %%
ft.shape
# Out:
# (555719, 23)

# %%
ft1.shape
# Out:
# (555719, 23)

# %%
df.nunique()
# Out:
# Unnamed: 0               1296675
# trans_date_trans_time    1274791
# cc_num                       983
# merchant                     693
# category                      14
# amt                        52928
# first                        352
# last                         481
# gender                         2
# street                       983
# city                         894
# state                         51
# zip                          970
# lat                          968
# long                         969
# city_pop                     879
# job                          494
# dob                          968
# trans_num                1296675
# unix_time                1274823
# merch_lat                1247805
# merch_long               1275745
# is_fraud                       2
# dtype: int64

# %%
ft.nunique()
# Out:
# Unnamed: 0               555719
# trans_date_trans_time    544760
# cc_num                      924
# merchant                    693
# category                     14
# amt                       37256
# first                       341
# last                        471
# gender                        2
# street                      924
# city                        849
# state                        50
# zip                         912
# lat                         910
# long                        910
# city_pop                    835
# job                         478
# dob                         910
# trans_num                555719
# unix_time                544760
# merch_lat                546490
# merch_long               551770
# is_fraud                      2
# dtype: int64

# %%
ft1.nunique()
# Out:
# Unnamed: 0               555719
# trans_date_trans_time    544760
# cc_num                      924
# merchant                    693
# category                     14
# amt                       37256
# first                       341
# last                        471
# gender                        2
# street                      924
# city                        849
# state                        50
# zip                         912
# lat                         910
# long                        910
# city_pop                    835
# job                         478
# dob                         910
# trans_num                555719
# unix_time                544760
# merch_lat                546490
# merch_long               551770
# is_fraud                      2
# dtype: int64

# %%
print('Total 0 in is_fraud: {}'.format(len(df[df['is_fraud'] == 0])))
print('Total 1 in is_fraud: {}'.format(len(df[df['is_fraud'] == 1])))
# Out:
# Total 0 in is_fraud: 1289169
# Total 1 in is_fraud: 7506

# %%
print('Total 0 in is_fraud: {}'.format(len(ft[ft['is_fraud'] == 0])))
print('Total 1 in is_fraud: {}'.format(len(ft[ft['is_fraud'] == 1])))
# Out:
# Total 0 in is_fraud: 553574
# Total 1 in is_fraud: 2145

# %%
print('Total 0 in is_fraud: {}'.format(len(ft1[ft1['is_fraud'] == 0])))
print('Total 1 in is_fraud: {}'.format(len(ft1[ft1['is_fraud'] == 1])))
# Out:
# Total 0 in is_fraud: 553574
# Total 1 in is_fraud: 2145

# %%
df.isnull().sum()
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %%
ft.isnull().sum()
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %%
ft1.isnull().sum()
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %%
# Removed columns name
# Unnamed

# %%
df = df[['first','last','gender','dob','street','city','state','zip','lat','long','city_pop','job','trans_date_trans_time','trans_num','amt','unix_time','merchant','category','merch_lat','merch_long','is_fraud']]
ft = ft[['first','last','gender','dob','street','city','state','zip','lat','long','city_pop','job','trans_date_trans_time','trans_num','amt','unix_time','merchant','category','merch_lat','merch_long','is_fraud']]
ft1 = ft1[['first','last','gender','dob','street','city','state','zip','lat','long','city_pop','job','trans_date_trans_time','trans_num','amt','unix_time','merchant','category','merch_lat','merch_long','is_fraud']]

# %%
df.head()
# Out:
#        first     last gender         dob                        street  \
# 0   Jennifer    Banks      F  1988-03-09                561 Perry Cove
# 1  Stephanie     Gill      F  1978-06-21  43039 Riley Greens Suite 393
# 2     Edward  Sanchez      M  1962-01-19      594 White Dale Suite 530
# 3     Jeremy    White      M  1967-01-12   9443 Cynthia Court Apt. 038
# 4      Tyler   Garcia      M  1986-03-28              408 Bradley Rest
#
#              city state    zip      lat      long  ...  \
# 0  Moravian Falls    NC  28654  36.0788  -81.1781  ...
# 1          Orient    WA  99160  48.8878 -118.2105  ...
# 2      Malad City    ID  83252  42.1808 -112.2620  ...
# 3         Boulder    MT  59632  46.2306 -112.1138  ...
# 4        Doe Hill    VA  24433  38.4207  -79.4629  ...
#
#                                  job trans_date_trans_time  \
# 0          Psychologist, counselling   2019-01-01 00:00:18
# 1  Special educational needs teacher   2019-01-01 00:00:44
# ...

# %%
ft.head()
# Out:
#     first      last gender         dob                       street  \
# 0    Jeff   Elliott      M  1968-03-19            351 Darlene Green
# 1  Joanne  Williams      F  1990-01-17             3638 Marsh Union
# 2  Ashley     Lopez      F  1970-10-21         9333 Valentine Point
# 3   Brian  Williams      M  1987-07-25  32941 Krystal Mill Apt. 552
# 4  Nathan    Massey      M  1955-07-06     5783 Evan Roads Apt. 465
#
#          city state    zip      lat      long  ...                     job  \
# 0    Columbia    SC  29209  33.9659  -80.9355  ...     Mechanical engineer
# 1     Altonah    UT  84002  40.3207 -110.4360  ...  Sales professional, IT
# 2    Bellmore    NY  11710  40.6729  -73.5365  ...       Librarian, public
# 3  Titusville    FL  32780  28.5697  -80.8191  ...            Set designer
# 4    Falmouth    MI  49632  44.2529  -85.0170  ...      Furniture designer
#
#   trans_date_trans_time                         trans_num    amt   unix_time  \
# ...

# %%
ft1.head()
# Out:
#     first      last gender         dob                       street  \
# 0    Jeff   Elliott      M  1968-03-19            351 Darlene Green
# 1  Joanne  Williams      F  1990-01-17             3638 Marsh Union
# 2  Ashley     Lopez      F  1970-10-21         9333 Valentine Point
# 3   Brian  Williams      M  1987-07-25  32941 Krystal Mill Apt. 552
# 4  Nathan    Massey      M  1955-07-06     5783 Evan Roads Apt. 465
#
#          city state    zip      lat      long  ...                     job  \
# 0    Columbia    SC  29209  33.9659  -80.9355  ...     Mechanical engineer
# 1     Altonah    UT  84002  40.3207 -110.4360  ...  Sales professional, IT
# 2    Bellmore    NY  11710  40.6729  -73.5365  ...       Librarian, public
# 3  Titusville    FL  32780  28.5697  -80.8191  ...            Set designer
# 4    Falmouth    MI  49632  44.2529  -85.0170  ...      Furniture designer
#
#   trans_date_trans_time                         trans_num    amt   unix_time  \
# ...

# %%
# columns operaton with different methods
# first- remove
# last- remove
# gender- LabelEncoder
# dob- remove
# street- remove
# city- LabelEncoder
# state- LabelEncoder
# zip- no change
# lat- remove
# long- remove
# city_pop- remove
# job- LabelEncoder
# trans_date_trans_time- remove
# trans_num- remove
# amt- no change
# unix_time- remove
# merchant- remove
# category- LabelEncoder
# merch_lat- remove
# merch_long- remove
# is_fraud- output

# %%
df = df[['amt','gender','city','state','zip','job','category','is_fraud']]
ft = ft[['amt','gender','city','state','zip','job','category','is_fraud']]
ft1 = ft1[['amt','gender','city','state','zip','job','category','is_fraud']]

# %%
df.head()
# Out:
#       amt gender            city state    zip  \
# 0    4.97      F  Moravian Falls    NC  28654
# 1  107.23      F          Orient    WA  99160
# 2  220.11      M      Malad City    ID  83252
# 3   45.00      M         Boulder    MT  59632
# 4   41.96      M        Doe Hill    VA  24433
#
#                                  job       category  is_fraud
# 0          Psychologist, counselling       misc_net         0
# 1  Special educational needs teacher    grocery_pos         0
# 2        Nature conservation officer  entertainment         0
# 3                    Patent attorney  gas_transport         0
# 4     Dance movement psychotherapist       misc_pos         0

# %%
for i in range(ft1['is_fraud'].shape[0]):
    if ft1['is_fraud'][i]==1:
        print(i)
# Out:
# 1685
# 1767
# 1781
# 1784
# 1857
# 1891
# 1906
# 1956
# 1968
# 2026
# 2039
# 2173
# 2195
# 2258
# 2467
# 2495
# 2506
# 2650
# 5669
# 5757
# 5940
# 6023
# 10036
# 10047
# 10167
# 10193
# 10206
# 11666
# 11669
# 11702
# 11710
# 11770
# 11780
# 11789
# 11799
# 11831
# 11842
# 13345
# 13741
# 13806
# 13876
# 13897
# 14043
# 14064
# 14386
# 14678
# 15411
# 16050
# 16078
# 16155
# 16196
# 16229
# 16231
# 16326
# 16365
# 16442
# 16575
# 17711
# 18142
# 18458
# 18487
# 18509
# 18534
# 18537
# 18572
# 18885
# 19034
# 19392
# 21721
# 21747
# 21937
# 21953
# 22015
# 22087
# 22236
# 22256
# 22353
# 22379
# 22427
# 22547
# 23015
# 23216
# 24869
# 25792
# 25893
# 25921
# 25997
# 26013
# 26055
# 26088
# 26098
# 26139
# 26160
# 26161
# 26163
# 26194
# 26219
# 26231
# 26239
# 26363
# 26379
# 26397
# 26446
# 26466
# 26477
# 26519
# 26567
# 26586
# 26602
# 26607
# 26615
# 26633
# 26673
# 26696
# 26780
# 26825
# 27436
# 27783
# 28628
# 29120
# 29593
# 29664
# 29716
# 29765
# 29795
# 29859
# 29894
# ...

# %%
print(ft['amt'][1685])
print(ft['gender'][1685])
print(ft['city'][1685])
print(ft['state'][1685])
print(ft['zip'][1685])
print(ft['job'][1685])
print(ft['category'][1685])
print(ft['is_fraud'][1685])
# Out:
# 24.84
# 0
# 557
# 42
# 779
# 109
# 5
# 1

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
df['gender'] = LE.fit_transform(df['gender'])
df['city'] = LE.fit_transform(df['city'])
df['state'] = LE.fit_transform(df['state'])
df['zip'] = LE.fit_transform(df['zip'])
df['job'] = LE.fit_transform(df['job'])
df['category'] = LE.fit_transform(df['category'])

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
ft['gender'] = LE.fit_transform(ft['gender'])
ft['city'] = LE.fit_transform(ft['city'])
ft['state'] = LE.fit_transform(ft['state'])
ft['zip'] = LE.fit_transform(ft['zip'])
ft['job'] = LE.fit_transform(ft['job'])
ft['category'] = LE.fit_transform(ft['category'])

# %%
X = df.iloc[:,:-1]
Y = df.iloc[:,-1]

# %%
X1 = ft.iloc[:,:-1]
Y1 = ft.iloc[:,-1]
X1
# Out:
#            amt  gender  city  state  zip  job  category
# 0         2.86       1   157     39  254  275        10
# 1        29.84       0    16     43  811  392        10
# 2        41.28       0    61     33   69  259         5
# 3        60.05       1   764      8  291  407         9
# 4         3.19       1   247     21  478  196        13
# ...        ...     ...   ...    ...  ...  ...       ...
# 555714   43.77       1   443     23  618  460         5
# 555715  111.84       1   401     42  763  198         7
# 555716   86.88       0   104     46  908  294         7
# 555717    7.99       1   476     12  808   58        13
# 555718   38.13       1   224     35  706  276         0
#
# [555719 rows x 7 columns]

# %%
X2 = ft1.iloc[:,:-1]
Y2 = ft1.iloc[:,-1]

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticCl
from sklearn.metrics import accuracy_score
LR = LogisticRegression(max_iter=1000)
LR.fit(X,Y)
Y_pred = LR.predict(X1)
accuracy_score(Y1,Y_pred)

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import r2_score
DT = DecisionTreeClassifier()
DT.fit(X,Y)
Y_pred = DT.predict(X1)
r2_score(Y1,Y_pred)
# Out:
# -0.08249998149343196

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import r2_score
RF = RandomForestClassifier(n_estimators=50)
RF.fit(X,Y)
RF.predict([[620.33,1,64,47,515,367,0]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
# RF.predict([[24.84,0,557,42,779,109,5]])
# 2.86,1,157,39,254,275,10
y_pred=RF.predict(X1)
r2_score(Y1,y_pred)
# Out:
# 0.37801881737796317

# %% [markdown]
# ## Navie Bayes

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
NB = GaussianNB()
NB.fit(X,Y)
y_pred = NB.predict(X1)
accuracy_score(Y1,y_pred)
# Out:
# 0.992073332025718

# %%
import pickle
pickle.dump(df,open('CreditCardFraud.pkl','wb'))

# %%
import pickle
pickle.dump(ft1,open('TestCreditCardFraud.pkl','wb'))
